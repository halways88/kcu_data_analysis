# %%
import pandas as pd

# %%
listings = pd.read_csv("listings.csv")

# %%
listings
# Out:
#             id                            listing_url       scrape_id  \
# 0     12147973  https://www.airbnb.com/rooms/12147973  20160906204935
# 1      3075044   https://www.airbnb.com/rooms/3075044  20160906204935
# 2         6976      https://www.airbnb.com/rooms/6976  20160906204935
# 3      1436513   https://www.airbnb.com/rooms/1436513  20160906204935
# 4      7651065   https://www.airbnb.com/rooms/7651065  20160906204935
# ...        ...                                    ...             ...
# 3580   8373729   https://www.airbnb.com/rooms/8373729  20160906204935
# 3581  14844274  https://www.airbnb.com/rooms/14844274  20160906204935
# 3582  14585486  https://www.airbnb.com/rooms/14585486  20160906204935
# 3583  14603878  https://www.airbnb.com/rooms/14603878  20160906204935
# 3584  14504422  https://www.airbnb.com/rooms/14504422  20160906204935
#
#      last_scraped                                           name  \
# ...

# %%
listings = listings[['name', 'id', 'latitude', 'longitude', 'property_type', 'room_type', 'bathrooms', 'bedrooms', 'amenities', 'price', 'cleaning_fee', 'cancellation_policy', 'reviews_per_month', 'review_scores_rating', 'review_scores_accuracy', 'review_scores_cleanliness', 'review_scores_checkin', 'review_scores_communication', 'review_scores_location', 'review_scores_value']]

# %%
location = []
for i in range(len(listings)):
    location_set = (listings['latitude'][i], listings['longitude'][i])
    location_list = list(location_set)
    location.append(location_list)

# %%
listings.insert(2, "gps", location, True)

# %%
listings.drop(columns=['longitude', 'latitude'])
# Out:
#                                                name        id  \
# 0                        Sunny Bungalow in the City  12147973
# 1                 Charming room in pet friendly apt   3075044
# 2                  Mexican Folk Art Haven in Boston      6976
# 3     Spacious Sunny Bedroom Suite in Historic Home   1436513
# 4                               Come Home to Boston   7651065
# ...                                             ...       ...
# 3580                           Big cozy room near T   8373729
# 3581            BU Apartment DexterPark Bright room  14844274
# 3582                       Gorgeous funky apartment  14585486
# 3583          Great Location; Train and Restaurants  14603878
# 3584             (K1) Private Room near Harvard/MIT  14504422
#
#                                            gps property_type        room_type  \
# 0      [42.28261879577949, -71.13306792912681]         House  Entire home/apt
# ...
